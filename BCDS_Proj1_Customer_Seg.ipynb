# %% [markdown]
# # Customer Segmentation in a Lisbon Hotel Chain

# %% [markdown]
# The objective is to explore the historical customer information of a 4Star Hotel in Lisbon in order to segment customers and discover the distinguishing features of each group.
#
# This should allow market to have a better understanding of customers groups in order to better engage with the customer. These informations may impact several areas of interaction with the customer, eg:
# Marketing: channels, timings, reinforcement points, selling points,...
# Sales: Pricing , customer value,...
# Reception: Types of interaction,...

# %% [markdown]
# ## DataSet Description

# %% [markdown]
# Talk about the variables

# %% [markdown]
# ## Setup and Import

# %%
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import category_encoders as ce
import collections
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# Data Loading and Initial Analysis

# %%
ds = pd.read_csv(r'data\dataset.csv', sep=";")
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111733 entries, 0 to 111732
# Data columns (total 29 columns):
# ID                      111733 non-null int64
# Nationality             111733 non-null object
# Age                     107561 non-null float64
# DaysSinceCreation       111733 non-null int64
# NameHash                111733 non-null object
# DocIDHash               110732 non-null object
# AverageLeadTime         111733 non-null int64
# LodgingRevenue          111733 non-null float64
# OtherRevenue            111733 non-null float64
# BookingsCanceled        111733 non-null int64
# BookingsNoShowed        111733 non-null int64
# BookingsCheckedIn       111733 non-null int64
# PersonsNights           111733 non-null int64
# RoomNights              111733 non-null int64
# DistributionChannel     111733 non-null object
# MarketSegment           111733 non-null object
# SRHighFloor             111733 non-null int64
# SRLowFloor              111733 non-null int64
# SRAccessibleRoom        111733 non-null int64
# SRMediumFloor           111733 non-null int64
# SRBathtub               111733 non-null int64
# SRShower                111733 non-null int64
# SRCrib                  111733 non-null int64
# SRKingSizeBed           111733 non-null int64
# SRTwinBed               111733 non-null int64
# SRNearElevator          111733 non-null int64
# SRAwayFromElevator      111733 non-null int64
# SRNoAlcoholInMiniBar    111733 non-null int64
# SRQuietRoom             111733 non-null int64
# dtypes: float64(3), int64(21), object(5)
# memory usage: 24.7+ MB

# %%
# Display top 10 rows transposed to show all columns
ds.head(10).transpose()
# Out:
#                                                                       0  \
# ID                                                                    1
# Nationality                                                         PRT
# Age                                                                  52
# DaysSinceCreation                                                   440
# NameHash              0x2C371FD6CE12936774A139FD7430C624F1C4D5109CE6...
# DocIDHash             0x434FD3D59469C73AFEA087017FAF8CA2296493AEABDE...
# AverageLeadTime                                                      59
# LodgingRevenue                                                      292
# OtherRevenue                                                       82.3
# BookingsCanceled                                                      1
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     2
# PersonsNights                                                         6
# RoomNights                                                            4
# DistributionChannel                                           Corporate
# MarketSegment                                                 Corporate
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       1  \
# ID                                                                    2
# Nationality                                                         PRT
# Age                                                                 NaN
# DaysSinceCreation                                                  1385
# NameHash              0x198CDB98BF37B6E23F9548C56A88B00912D65A9AA0D6...
# DocIDHash             0xE3B0C44298FC1C149AFBF4C8996FB92427AE41E4649B...
# AverageLeadTime                                                      61
# LodgingRevenue                                                      280
# OtherRevenue                                                         53
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     1
# PersonsNights                                                        10
# RoomNights                                                            5
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                     Travel Agent/Operator
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       2  \
# ID                                                                    3
# Nationality                                                         DEU
# Age                                                                  32
# DaysSinceCreation                                                  1385
# NameHash              0xDA46E62F66936284DF2844EC4FC542D0DAD780C0EE0C...
# DocIDHash             0x27F5DF762CCDA622C752CCDA45794923BED9F1B66300...
# AverageLeadTime                                                       0
# LodgingRevenue                                                        0
# OtherRevenue                                                          0
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     0
# PersonsNights                                                         0
# RoomNights                                                            0
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                     Travel Agent/Operator
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       3  \
# ID                                                                    4
# Nationality                                                         FRA
# Age                                                                  61
# DaysSinceCreation                                                  1385
# NameHash              0xC45D4CD22C58FDC5FD0F95315F6EFA5A6E7149187D49...
# DocIDHash             0x8E59572913BB9B1E6CAA12FA2C8B7BF387B1D1F3432E...
# AverageLeadTime                                                      93
# LodgingRevenue                                                      240
# OtherRevenue                                                         60
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     1
# PersonsNights                                                        10
# RoomNights                                                            5
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                     Travel Agent/Operator
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       4  \
# ID                                                                    5
# Nationality                                                         FRA
# Age                                                                  52
# DaysSinceCreation                                                  1385
# NameHash              0xD2E3D5BFCA141865669F98D64CDA85AD04DEFF47F8A0...
# DocIDHash             0x42BDEE0E05A9441C94147076EDDCC47E604DA5447DD4...
# AverageLeadTime                                                       0
# LodgingRevenue                                                        0
# OtherRevenue                                                          0
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     0
# PersonsNights                                                         0
# RoomNights                                                            0
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                     Travel Agent/Operator
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       5  \
# ID                                                                    6
# Nationality                                                         JPN
# Age                                                                  55
# DaysSinceCreation                                                  1385
# NameHash              0xA3CF1A4692BE0A17CFD3BFD9C07653556BDADF5F4BE7...
# DocIDHash             0x506065FBCE220DCEA4465C7310A84F04165BCB5906DC...
# AverageLeadTime                                                      58
# LodgingRevenue                                                      230
# OtherRevenue                                                         24
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     1
# PersonsNights                                                         4
# RoomNights                                                            2
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                                     Other
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       6  \
# ID                                                                    7
# Nationality                                                         JPN
# Age                                                                  50
# DaysSinceCreation                                                  1385
# NameHash              0x94DB830C90A6DA2331968CFC9448AB9A3CE07D7CFEDD...
# DocIDHash             0x47E5E4B21585F1FD956C768E730604241B380EDFEA68...
# AverageLeadTime                                                       0
# LodgingRevenue                                                        0
# OtherRevenue                                                          0
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     0
# PersonsNights                                                         0
# RoomNights                                                            0
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                                     Other
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       7  \
# ID                                                                    8
# Nationality                                                         FRA
# Age                                                                  33
# DaysSinceCreation                                                  1385
# NameHash              0x165B609162C92BF563E96DB03539363F07E784C219A8...
# DocIDHash             0x6BB66BA80C726B9967988A889D83699B609D11C65AD7...
# AverageLeadTime                                                      38
# LodgingRevenue                                                      535
# OtherRevenue                                                         94
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     1
# PersonsNights                                                        10
# RoomNights                                                            5
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                                     Other
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         1
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       8  \
# ID                                                                    9
# Nationality                                                         FRA
# Age                                                                  43
# DaysSinceCreation                                                  1385
# NameHash              0x44BB41EF2D87698E75B6FBB77A8815BF48DAA912C140...
# DocIDHash             0x6C456E45A78A20BC794137AE326A81D587B6528B3944...
# AverageLeadTime                                                       0
# LodgingRevenue                                                        0
# OtherRevenue                                                          0
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     0
# PersonsNights                                                         0
# RoomNights                                                            0
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                                     Other
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         1
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0
#
#                                                                       9
# ID                                                                   10
# Nationality                                                         IRL
# Age                                                                  26
# DaysSinceCreation                                                  1385
# NameHash              0x9BEECEE0C18B0957C7424443643948E99A0EC8326EF9...
# DocIDHash             0x199C61A5442D08987001E170B74D244DF6AF1FC9AE92...
# AverageLeadTime                                                      96
# LodgingRevenue                                                      174
# OtherRevenue                                                         69
# BookingsCanceled                                                      0
# BookingsNoShowed                                                      0
# BookingsCheckedIn                                                     1
# PersonsNights                                                         6
# RoomNights                                                            3
# DistributionChannel                               Travel Agent/Operator
# MarketSegment                                     Travel Agent/Operator
# SRHighFloor                                                           0
# SRLowFloor                                                            0
# SRAccessibleRoom                                                      0
# SRMediumFloor                                                         0
# SRBathtub                                                             0
# SRShower                                                              0
# SRCrib                                                                0
# SRKingSizeBed                                                         0
# SRTwinBed                                                             0
# SRNearElevator                                                        0
# SRAwayFromElevator                                                    0
# SRNoAlcoholInMiniBar                                                  0
# SRQuietRoom                                                           0

# %%
# Summary statistics for numerical variables
summary=ds.describe(exclude=[np.object])   # exclude only objects, they will be treated next
summary=summary.transpose()  # transpose the summary for easier reading
summary.head(len(summary))
# Out:
#                          count          mean           std   min      25%  \
# ID                    111733.0  55867.000000  32254.683151   1.0  27934.0
# Age                   107561.0     45.639191     17.244952 -10.0     33.0
# DaysSinceCreation     111733.0    595.026599    374.657382  36.0    288.0
# AverageLeadTime       111733.0     60.833147     85.115320  -1.0      0.0
# LodgingRevenue        111733.0    283.851283    379.131556   0.0      0.0
# OtherRevenue          111733.0     64.682802    123.580715   0.0      0.0
# BookingsCanceled      111733.0      0.002282      0.080631   0.0      0.0
# BookingsNoShowed      111733.0      0.000600      0.028217   0.0      0.0
# BookingsCheckedIn     111733.0      0.737607      0.730889   0.0      0.0
# PersonsNights         111733.0      4.328318      4.630739   0.0      0.0
# RoomNights            111733.0      2.203825      2.301637   0.0      0.0
# SRHighFloor           111733.0      0.042512      0.201755   0.0      0.0
# SRLowFloor            111733.0      0.001307      0.036125   0.0      0.0
# SRAccessibleRoom      111733.0      0.000224      0.014957   0.0      0.0
# SRMediumFloor         111733.0      0.000770      0.027733   0.0      0.0
# SRBathtub             111733.0      0.003132      0.055881   0.0      0.0
# SRShower              111733.0      0.001629      0.040327   0.0      0.0
# SRCrib                111733.0      0.016181      0.126173   0.0      0.0
# SRKingSizeBed         111733.0      0.363268      0.480943   0.0      0.0
# SRTwinBed             111733.0      0.156811      0.363624   0.0      0.0
# SRNearElevator        111733.0      0.000331      0.018195   0.0      0.0
# SRAwayFromElevator    111733.0      0.003598      0.059874   0.0      0.0
# SRNoAlcoholInMiniBar  111733.0      0.000197      0.014031   0.0      0.0
# SRQuietRoom           111733.0      0.087718      0.282886   0.0      0.0
#
#                           50%      75%        max
# ID                    55867.0  83800.0  111733.00
# Age                      47.0     58.0     123.00
# DaysSinceCreation       522.0    889.0    1385.00
# AverageLeadTime          21.0     95.0     588.00
# LodgingRevenue          208.0    393.3   21781.00
# OtherRevenue             31.0     84.0    8859.25
# BookingsCanceled          0.0      0.0      15.00
# BookingsNoShowed          0.0      0.0       3.00
# BookingsCheckedIn         1.0      1.0      76.00
# PersonsNights             4.0      6.0     116.00
# RoomNights                2.0      3.0     185.00
# SRHighFloor               0.0      0.0       1.00
# SRLowFloor                0.0      0.0       1.00
# SRAccessibleRoom          0.0      0.0       1.00
# SRMediumFloor             0.0      0.0       1.00
# SRBathtub                 0.0      0.0       1.00
# SRShower                  0.0      0.0       1.00
# SRCrib                    0.0      0.0       1.00
# SRKingSizeBed             0.0      1.0       1.00
# SRTwinBed                 0.0      0.0       1.00
# SRNearElevator            0.0      0.0       1.00
# SRAwayFromElevator        0.0      0.0       1.00
# SRNoAlcoholInMiniBar      0.0      0.0       1.00
# SRQuietRoom               0.0      0.0       1.00

# %%
# Summary statistics for non numerical variables
summary=ds.describe(include=[np.object],percentiles=None)   
summary=summary.transpose()  
summary.head(len(summary))
# Out:
#                       count  unique  \
# Nationality          111733     199
# NameHash             111733  107584
# DocIDHash            110732  103480
# DistributionChannel  111733       4
# MarketSegment        111733       7
#
#                                                                    top   freq
# Nationality                                                        FRA  16516
# NameHash             0x15A713CE687991691A18F6CDC56ABE24979C73CF5D51...     75
# DocIDHash            0xE3B0C44298FC1C149AFBF4C8996FB92427AE41E4649B...   3032
# DistributionChannel                              Travel Agent/Operator  91019
# MarketSegment                                                    Other  63680

# %% [markdown]
# 199 Nationalities problems probably...
# We seem to have duplicates on Name Hashes and DocIDHashes , so we may have to do something about this

# %%
nationalities=list(set(ds.Nationality))
print(nationalities)
len(nationalities)
# Out:
# ['KOR', 'TGO', 'ECU', 'BHS', 'AIA', 'COM', 'BLR', 'UGA', 'SEN', 'HRV', 'TZA', 'DNK', 'RWA', 'THA', 'AGO', 'PNG', 'ALB', 'SLE', 'DOM', 'CPV', 'CMR', 'NCL', 'PAN', 'CRI', 'KNA', 'TJK', 'JPN', 'DEU', 'DMA', 'ABW', 'LTU', 'VIR', 'EST', 'BEL', 'SOM', 'MAR', 'ASM', 'COK', 'WSM', 'VEN', 'VNM', 'GHA', 'HTI', 'CHN', 'KAZ', 'BMU', 'TMP', 'FIN', 'GIB', 'ISL', 'SUR', 'SWZ', 'CYP', 'ESP', 'UKR', 'RUS', 'KEN', 'GNQ', 'CZE', 'SPM', 'IRL', 'GEO', 'TON', 'BFA', 'AFG', 'NLD', 'MKD', 'GBR', 'ITA', 'TUR', 'PAK', 'DZA', 'MOZ', 'IOT', 'CYM', 'MUS', 'USA', 'IRQ', 'ISR', 'MNE', 'TCD', 'ARG', 'CAN', 'ETH', 'BIH', 'BGD', 'IRN', 'BGR', 'GIN', 'MDV', 'ERI', 'BEN', 'MLI', 'FJI', 'NRU', 'BHR', 'AUS', 'QAT', 'LKA', 'PRY', 'ATA', 'SYC', 'ROU', 'GRC', 'PRI', 'URY', 'LBY', 'MMR', 'YEM', 'VCT', 'FRO', 'JOR', 'MDG', 'KWT', 'GUF', 'PCN', 'NOR', 'PYF', 'LCA', 'LUX', 'GRD', 'TTO', 'ATG', 'FSM', 'MWI', 'GTM', 'KGZ', 'PER', 'HUN', 'LVA', 'SDN', 'NAM', 'BDI', 'SMR', 'BRB', 'SWE', 'LBN', 'ZWE', 'POL', 'FLK', 'PHL', 'EGY', 'NZL', 'OMN', 'SAU', 'PRT', 'TWN', 'ARM', 'UZB', 'LAO', 'AND', 'CHE', 'BOL', 'CUB', 'JEY', 'GNB', 'CIV', 'ZAF', 'CAF', 'MRT', 'HND', 'SVK', 'JAM', 'GAB', 'WLF', 'IND', 'TKM', 'UMI', 'KIR', 'GUY', 'SJM', 'MYS', 'ATF', 'LIE', 'IDN', 'MLT', 'ARE', 'NER', 'COL', 'AUT', 'BRA', 'AZE', 'CHL', 'MEX', 'BWA', 'FRA', 'SRB', 'MCO', 'COD', 'SGP', 'NPL', 'NIC', 'SLV', 'SVN', 'STP', 'SYR', 'HKG', 'NGA', 'TUN']
# 199

# %%
#Check the document hashes
print(ds["DocIDHash"].value_counts(sort=True).head(60))
# Out:
# 0xE3B0C44298FC1C149AFBF4C8996FB92427AE41E4649B934CA495991B7852B855    3032
# 0xA486FBACF4B4E5537B026743E3FDFE571D716839E758236F42950A61FE6B922B      31
# 0x2B17E9D2CCEF2EA0FE752EE345BEDFB06741FFC8ECECF45D6BBDBAF9A274FF52      24
# 0x469CF1F9CF8C790FFA5AD3F484F2938CBEFF6435BCFD734F687EC6D1E968F076      15
# 0x2A14D03A4827C67E0D39408F103DB417AD496DCE6158F8309E6281185C042003      14
# 0x9220D336F2DDD7B68F5066878889C7637EE28924B249F968F5EC82D895B108A7      12
# 0x3856085146F7BC27BD07BFC4CA1991ED4E65E179D7BDB7DBBA7E32620809C799      12
# 0xD2DBD6039916F6DB10C6564D8EB9A9116811435965D7D00E7DA292066B3ECE91      11
# 0x1BF60C4718497A0AB8B46FF00708D3250A484DDA0FDC0248999C782807195BCB      11
# 0x8FA8EB6D044E4F2C691C2091FAB27B92FEFE22122F419975703C3D5BA76AC4A2      10
# 0xA89022F442F23A6D7486C47C9F968BF35898B36F0EB3531804CA4613FF33DC45      10
# 0x10DFBA7DC4CFBBC6403B380AE137098B254DBBCBE5DEEB0C3B240E0F12F0C6D4      10
# 0x6B421376B94F3D1722979458A96DF486DEA0F9290CC05E9699F2762FD0DDA71D      10
# 0x1B16B1DF538BA12DC3F97EDBB85CAA7050D46C148134290FEBA80F8236C83DB9      10
# 0x951CBCCC0D930B22DF4E9C1B56FE23A240281087B331E53DB453A72EA82CD5B3      10
# 0x4C6B6D8800C9C655490B1A6AF049770E20404E0B464C8CD2A3F5A88726F3F823      10
# 0xEC3C8CB40B1F7BFC4ECDEA7AD79DBE62963891748F2C21C759373DCD3C1029E2       9
# 0x4DA48EED943299176444C244EAA74FACB04E8E66DE8263CAD48A0AC337F36144       9
# 0xF8EF4A96388E532BE299CD1E57FE4E2E3BC727EAD918E7A3A004C683E4269DF1       9
# 0xAC6327FBF3BC88667FE712AC1CEB095E3E88DB6D55478C0A6C826DD0540B83EF       9
# 0xD0F9C521479A276F760AA2B7A922B1E96F982439388E101341B3BDFDB97163C2       9
# 0xC03D1A33F1B55588E4DCB93419BC87712EA0BCABFB3C8613EB16E069F76B877F       8
# 0xD09DC90EE2E486D3C43D74612223BF3E2180CBE05C5C59A17C5374FACF7DEB86       8
# 0xE76926D097F612D921A7494C6B18247BF7DBA28D0679960312DF2AD5DB7F37BD       8
# 0xA5D8D6FD5CEF0EF390545C4CF424EAF309A0BD04262672D29F20D732B8678338       8
# 0x776FB232A8F52A7E0B1D176B81641982C10545AA7EB5EDD77FF6D15C30DF0B6A       8
# 0x32486B5C95409439A72B10899814F8A34F4E4FACD16E0E857E7453C65C182715       8
# 0xC548B0AFF954B3075C9EC91618BDA2DBE94DD2FF6991598C689E2E5865BD7C97       8
# 0x8BD3E95C192EB4A4F4885DE22354B6D3DCBB019E328890C6B1A9C3606941E607       8
# 0x7FA92388263683A1B2F68F10EAB83779B52DF2FEBF2BAED76333D9FF9B3BD16B       8
# 0x19AEA473821801F4C5AFA2BC5AB83B10D1C0E12B8E1B67A885D832340F3100F8       8
# 0x55121C172CF624F0DF0CA82CB8ABCEF490BE9F03901E45D73DCA8F1584FEC29C       7
# 0x11133654B2F9C795ED159AD2B9D458C99CD8C924DDCBA43DD63D548C0538BF43       7
# 0x26BC81BC08AFD36E3C5669BE6B8F729FBDA60AE61D2B0E4E92E5AD04D510A08B       7
# 0x2AF3B6435B885727B77E725749030B4ED5D2F6AB8BB943C8ED375FEDBE427E91       7
# 0x918C42080E2E417137B6274BD863F427658DA27FE11E1809DAB4B39A53C14578       7
# 0xA48228BEB6FDA0E41844789716EC6C3F5B5328B9FA6ED0A41A36AC1E7BE62866       7
# 0xC86F4E5676B610E9A6F1AB6024A81B0F9FC6DDF8558C34E4DA5F794E1A0B93B7       7
# 0x9FAED896E692E3F9470A2AD6166BE79B31A9086FDB07A1B9BB7EB9463D8DCA6D       7
# 0xCE9E812B30BC6F0FEC06357B970075E474FAC07551EB1010D3C2402E1D82AD1B       7
# 0xE743A82AF701A15DC8CF79597004179B4855E4A8C5BCD1A0DFE45A3DD1B08187       7
# 0x509F262E93D0CFAAF414A43436062C60AC7ABF3BA4D453DDF3F3A116ECBFF13F       7
# 0x388F5F9655F4C8717E5FAC73F1F4E71248602FCAA11AE811D20CCCEFB46E3BDA       7
# 0x66A480C28516E87A4E6FC2680E3461DC2A710C923E70150D2EB82FCF136F503E       7
# 0x8B3BBE67C6C4558D3B641571B7DA26B319F65749680B81A7D2461C69A34A3064       7
# 0x96ACBF97EBD3B77A1E0A1B1169F04D8C3CF8B0D08BEE9105F752BA8CC361DE55       7
# 0xB462263B16B5CF68BDDBDC9AFFE1527A11FB9870B4D2C74272C065FF5C61E520       7
# 0x8FEA25577B5C3BD878128DFDF0EE140B7CEBE5F2BFCC2EEF6E2170470E9F663A       7
# 0xEE9FCDBEFB65F518BB131D61248490F17244549E5865497F1DDA9BEF5259B92D       7
# 0x5912B6E01CFF23A2C40C3A2AE78D5D1103D4E2EB84F9FF4A15833F633C967A4A       7
# 0x050E92308C06EABFBF8EE2CB085747B48344377704AC1256DE5F961879601A4A       7
# 0x7CC568500E7D63F938C532073C8FB438F67E1F1F6AF9C8409D1BE3F9ABA4CE5D       6
# 0x9C4C4EC297BD58967A9F7DDA852AAC11EA8E3E85F00EEEA24F969A903CB2ABCE       6
# 0x2D9BEC84260850B23A09E2A6CE9CAD597B53ABAD19BD1BD8C7EA8F867004D28F       6
# 0x4CCCD23533945121FF7A662A00A34BB72AD04072BE178B895860AC36B09A9E4C       6
# 0x12207181F55CE449454BB5804745174CAC65C5CFCE10EFAA527B24A7F9BA6E42       6
# 0xA88DA5EA2D3B1DCF78F4FD76C517B928C6197FD63AEA2C59244545E653AB669B       6
# 0x875083AAF87AD7ACA8BC4A0E95D6160E4FA65E5A43C2E8D06B5516DE1BB13001       6
# 0x2E00B44146F57B62A9658CC09246ED26F6A203BE37DA1F5C8A2580B99060068E       6
# 0x5A7283FBA63F631C4F2397E0610C9D3581DC910B396B1012CA781AA5C60CBE67       6
# Name: DocIDHash, dtype: int64

# %% [markdown]
# One recurring ID, way too many times to be a person, what to do with others?

# %%
from statistics import mode
doc_explore=ds.loc[ds['DocIDHash'] == (mode(ds["DocIDHash"]))]

summary=doc_explore.describe(include="all")
summary=summary.transpose()  
summary.head(len(summary))



#doc_explore.DistributionChannel.value_counts()
#doc_explore.MarketSegment.value_counts()
# Out:
#                      count unique  \
# ID                    3032    NaN
# Nationality           3032      3
# Age                    171    NaN
# DaysSinceCreation     3032    NaN
# NameHash              3032   2826
# DocIDHash             3032      1
# AverageLeadTime       3032    NaN
# LodgingRevenue        3032    NaN
# OtherRevenue          3032    NaN
# BookingsCanceled      3032    NaN
# BookingsNoShowed      3032    NaN
# BookingsCheckedIn     3032    NaN
# PersonsNights         3032    NaN
# RoomNights            3032    NaN
# DistributionChannel   3032      4
# MarketSegment         3032      7
# SRHighFloor           3032    NaN
# SRLowFloor            3032    NaN
# SRAccessibleRoom      3032    NaN
# SRMediumFloor         3032    NaN
# SRBathtub             3032    NaN
# SRShower              3032    NaN
# SRCrib                3032    NaN
# SRKingSizeBed         3032    NaN
# SRTwinBed             3032    NaN
# SRNearElevator        3032    NaN
# SRAwayFromElevator    3032    NaN
# SRNoAlcoholInMiniBar  3032    NaN
# SRQuietRoom           3032    NaN
#
#                                                                     top  freq  \
# ID                                                                  NaN   NaN
# Nationality                                                         PRT  3030
# Age                                                                 NaN   NaN
# DaysSinceCreation                                                   NaN   NaN
# NameHash              0x5175AC9E84362C505AED3E76F20320BE69DD1C21AA67...    10
# DocIDHash             0xE3B0C44298FC1C149AFBF4C8996FB92427AE41E4649B...  3032
# AverageLeadTime                                                     NaN   NaN
# LodgingRevenue                                                      NaN   NaN
# OtherRevenue                                                        NaN   NaN
# BookingsCanceled                                                    NaN   NaN
# BookingsNoShowed                                                    NaN   NaN
# BookingsCheckedIn                                                   NaN   NaN
# PersonsNights                                                       NaN   NaN
# RoomNights                                                          NaN   NaN
# DistributionChannel                               Travel Agent/Operator  2138
# MarketSegment                                                     Other  1160
# SRHighFloor                                                         NaN   NaN
# SRLowFloor                                                          NaN   NaN
# SRAccessibleRoom                                                    NaN   NaN
# SRMediumFloor                                                       NaN   NaN
# SRBathtub                                                           NaN   NaN
# SRShower                                                            NaN   NaN
# SRCrib                                                              NaN   NaN
# SRKingSizeBed                                                       NaN   NaN
# SRTwinBed                                                           NaN   NaN
# SRNearElevator                                                      NaN   NaN
# SRAwayFromElevator                                                  NaN   NaN
# SRNoAlcoholInMiniBar                                                NaN   NaN
# SRQuietRoom                                                         NaN   NaN
#
#                              mean        std  min      25%      50%      75%  \
# ID                          27711    24608.2    2  8240.25  20409.5  41602.8
# Nationality                   NaN        NaN  NaN      NaN      NaN      NaN
# Age                        39.924    17.1889    2       29       39     53.5
# DaysSinceCreation         939.059    330.527   38   690.75     1022     1219
# NameHash                      NaN        NaN  NaN      NaN      NaN      NaN
# DocIDHash                     NaN        NaN  NaN      NaN      NaN      NaN
# AverageLeadTime           66.7932    86.6466   -1        4       30   103.25
# LodgingRevenue            279.394    308.564    0  101.565      188  358.075
# OtherRevenue              74.2252    156.058    0       14       41       84
# BookingsCanceled       0.00758575  0.0905016    0        0        0        0
# BookingsNoShowed       0.00230871  0.0544425    0        0        0        0
# BookingsCheckedIn         1.01088    0.52789    0        1        1        1
# PersonsNights             4.47625    3.92062    0        2        4        6
# RoomNights                 2.3905    1.99584    0        1        2        3
# DistributionChannel           NaN        NaN  NaN      NaN      NaN      NaN
# MarketSegment                 NaN        NaN  NaN      NaN      NaN      NaN
# SRHighFloor             0.0257256   0.158342    0        0        0        0
# SRLowFloor            0.000659631   0.025679    0        0        0        0
# SRAccessibleRoom      0.000659631   0.025679    0        0        0        0
# SRMediumFloor         0.000659631   0.025679    0        0        0        0
# SRBathtub              0.00131926  0.0363037    0        0        0        0
# SRShower              0.000329815  0.0181608    0        0        0        0
# SRCrib                 0.00791557  0.0886313    0        0        0        0
# SRKingSizeBed             0.26814   0.443064    0        0        0        1
# SRTwinBed                0.133575   0.340251    0        0        0        0
# SRNearElevator                  0          0    0        0        0        0
# SRAwayFromElevator     0.00263852  0.0513072    0        0        0        0
# SRNoAlcoholInMiniBar            0          0    0        0        0        0
# SRQuietRoom             0.0286939   0.166972    0        0        0        0
#
#                          max
# ID                    111553
# Nationality              NaN
# Age                       83
# DaysSinceCreation       1385
# NameHash                 NaN
# DocIDHash                NaN
# AverageLeadTime          588
# LodgingRevenue          4255
# OtherRevenue          5105.5
# BookingsCanceled           2
# BookingsNoShowed           2
# BookingsCheckedIn         19
# PersonsNights             51
# RoomNights                51
# DistributionChannel      NaN
# MarketSegment            NaN
# SRHighFloor                1
# SRLowFloor                 1
# SRAccessibleRoom           1
# SRMediumFloor              1
# SRBathtub                  1
# SRShower                   1
# SRCrib                     1
# SRKingSizeBed              1
# SRTwinBed                  1
# SRNearElevator             0
# SRAwayFromElevator         1
# SRNoAlcoholInMiniBar       0
# SRQuietRoom                1

# %% [markdown]
# Maybe an alias for document not presented, or other situation? It has different ages, 2826 different Name Hashes.

# %%
#Check Distribution channel and Market Segment
doc_explore["DistributionChannel","MarketSegment"].apply(pd.Series.value_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('DistributionChannel', 'MarketSegment')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-c16dde63253f> in <module>
#       1 #Check Distribution channel and Market Segment
# ----> 2 doc_explore["DistributionChannel","MarketSegment"].apply(pd.Series.value_counts)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('DistributionChannel', 'MarketSegment')

# %% [markdown]
# None the less, we must think on the variables that are only available after arrival, since those cannot be used in the model, or predictions cannot be made before arrival.
#
# And documents are presented on arrival, but...

# %%
doc_explore=ds.loc[ds['DocIDHash'] == "0xA486FBACF4B4E5537B026743E3FDFE571D716839E758236F42950A61FE6B922B"]

summary=doc_explore.describe(include="all")
summary=summary.transpose()
summary.head(len(summary))
# Out:
#                      count unique  \
# ID                      31    NaN
# Nationality             31      1
# Age                     31    NaN
# DaysSinceCreation       31    NaN
# NameHash                31      9
# DocIDHash               31      1
# AverageLeadTime         31    NaN
# LodgingRevenue          31    NaN
# OtherRevenue            31    NaN
# BookingsCanceled        31    NaN
# BookingsNoShowed        31    NaN
# BookingsCheckedIn       31    NaN
# PersonsNights           31    NaN
# RoomNights              31    NaN
# DistributionChannel     31      1
# MarketSegment           31      1
# SRHighFloor             31    NaN
# SRLowFloor              31    NaN
# SRAccessibleRoom        31    NaN
# SRMediumFloor           31    NaN
# SRBathtub               31    NaN
# SRShower                31    NaN
# SRCrib                  31    NaN
# SRKingSizeBed           31    NaN
# SRTwinBed               31    NaN
# SRNearElevator          31    NaN
# SRAwayFromElevator      31    NaN
# SRNoAlcoholInMiniBar    31    NaN
# SRQuietRoom             31    NaN
#
#                                                                     top freq  \
# ID                                                                  NaN  NaN
# Nationality                                                         PRT   31
# Age                                                                 NaN  NaN
# DaysSinceCreation                                                   NaN  NaN
# NameHash              0x8DF2AF984365949E7F4EAB2EBA9BF9CA8DF106B5F2A9...   20
# DocIDHash             0xA486FBACF4B4E5537B026743E3FDFE571D716839E758...   31
# AverageLeadTime                                                     NaN  NaN
# LodgingRevenue                                                      NaN  NaN
# OtherRevenue                                                        NaN  NaN
# BookingsCanceled                                                    NaN  NaN
# BookingsNoShowed                                                    NaN  NaN
# BookingsCheckedIn                                                   NaN  NaN
# PersonsNights                                                       NaN  NaN
# RoomNights                                                          NaN  NaN
# DistributionChannel                                           Corporate   31
# MarketSegment                                                 Corporate   31
# SRHighFloor                                                         NaN  NaN
# SRLowFloor                                                          NaN  NaN
# SRAccessibleRoom                                                    NaN  NaN
# SRMediumFloor                                                       NaN  NaN
# SRBathtub                                                           NaN  NaN
# SRShower                                                            NaN  NaN
# SRCrib                                                              NaN  NaN
# SRKingSizeBed                                                       NaN  NaN
# SRTwinBed                                                           NaN  NaN
# SRNearElevator                                                      NaN  NaN
# SRAwayFromElevator                                                  NaN  NaN
# SRNoAlcoholInMiniBar                                                NaN  NaN
# SRQuietRoom                                                         NaN  NaN
#
#                           mean       std    min      25%    50%      75%  \
# ID                     51674.5     21078  12953  37829.5  48009  63716.5
# Nationality                NaN       NaN    NaN      NaN    NaN      NaN
# Age                         51         0     51       51     51       51
# DaysSinceCreation      602.645   241.352    142      460    588    745.5
# NameHash                   NaN       NaN    NaN      NaN    NaN      NaN
# DocIDHash                  NaN       NaN    NaN      NaN    NaN      NaN
# AverageLeadTime        13.5161   13.1779      0        4     10       20
# LodgingRevenue          778.16   1385.32     59      118    295    650.5
# OtherRevenue           114.056   197.622      7       17     44    112.5
# BookingsCanceled      0.290323   0.82436      0        0      0        0
# BookingsNoShowed      0.225806  0.560338      0        0      0        0
# BookingsCheckedIn      4.93548   7.91596      1        1      2        6
# PersonsNights          12.1613   22.2368      1        2      5       11
# RoomNights             12.0968   22.2146      1        2      5       11
# DistributionChannel        NaN       NaN    NaN      NaN    NaN      NaN
# MarketSegment              NaN       NaN    NaN      NaN    NaN      NaN
# SRHighFloor                  0         0      0        0      0        0
# SRLowFloor                   0         0      0        0      0        0
# SRAccessibleRoom             0         0      0        0      0        0
# SRMediumFloor                0         0      0        0      0        0
# SRBathtub                    0         0      0        0      0        0
# SRShower                     0         0      0        0      0        0
# SRCrib                       0         0      0        0      0        0
# SRKingSizeBed                1         0      1        1      1        1
# SRTwinBed                    0         0      0        0      0        0
# SRNearElevator               0         0      0        0      0        0
# SRAwayFromElevator           0         0      0        0      0        0
# SRNoAlcoholInMiniBar         0         0      0        0      0        0
# SRQuietRoom                  0         0      0        0      0        0
#
#                         max
# ID                    98732
# Nationality             NaN
# Age                      51
# DaysSinceCreation      1147
# NameHash                NaN
# DocIDHash               NaN
# AverageLeadTime          50
# LodgingRevenue         6991
# OtherRevenue            957
# BookingsCanceled          4
# BookingsNoShowed          2
# BookingsCheckedIn        40
# PersonsNights           116
# RoomNights              116
# DistributionChannel     NaN
# MarketSegment           NaN
# SRHighFloor               0
# SRLowFloor                0
# SRAccessibleRoom          0
# SRMediumFloor             0
# SRBathtub                 0
# SRShower                  0
# SRCrib                    0
# SRKingSizeBed             1
# SRTwinBed                 0
# SRNearElevator            0
# SRAwayFromElevator        0
# SRNoAlcoholInMiniBar      0
# SRQuietRoom               0

# %% [markdown]
# For this second document hash, we see  some things that are equal across different records, the nationality, the age and we can see more consistency on the values.

# %%
perguntas: some columns are averages, the ones that are binary represent what? The requests of the last booking? What should we do with the records with the same document hash...
